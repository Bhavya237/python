# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Bhavya\Downloads\Udemy Courses Data.csv',parse_dates=['published_timestamp'])

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
data.shape
# Out:
# (3682, 11)

# %%
data.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.682000e+03      3682.000000   3682.000000   3682.000000
# mean   6.766121e+05      3194.230310    156.093156     40.065182
# std    3.436355e+05      9499.378361    934.957204     50.373299
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.078430e+05       110.250000      4.000000     15.000000
# 50%    6.885580e+05       911.500000     18.000000     25.000000
# 75%    9.617515e+05      2540.250000     67.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   datetime64[ns, UTC]
#  10  subject              3682 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(4), object(5)
# memory usage: 291.4+ KB

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data[data.duplicated()]
# Out:
#       course_id                                       course_title  is_paid  \
# 726     1084454                  CFA Level 2- Quantitative Methods     True
# 1186     837322  Essentials of money value: Get a financial Life !     True
# 1910    1157298  Introduction to Forex Trading Business For Beg...     True
# 2431      28295  Learn Web Designing & HTML5/CSS3 Essentials in...     True
# 2597     185526                             MicroStation - Células     True
# 3516    1035638                 Understanding Financial Statements     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 726     40                0            0            35      All Levels
# 1186    20                0            0            20      All Levels
# 1910    20                0            0            27  Beginner Level
# 2431    75            43285          525            24      All Levels
# 2597    20                0            0             9  Beginner Level
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data=data.drop_duplicates()

# %%
###Number of courses per subject

data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
data.groupby('subject')

# %%
data.groupby('subject')['course_title'].value_counts()
# Out:
# subject           course_title
# Business Finance  'Geometry Of Chance strategy of defeating the roulette."        1
#                   How to invest in Forex Trading & add an additional income       1
#                   How to invest in Russian equity market                          1
#                   How to read a Profit & Loss Account and Balance Sheet           1
#                   How to remove 'Risk from Penny Stocks - Options Trading"        1
#                                                                                  ..
# Web Development   Javascript for beginners                                        1
#                   Javascript from Beginner to Advanced Level                      1
#                   Jekyll: make fast, secure static sites and blogs with Jekyll    1
#                   Joomla 3 - The Basics                                           1
#                   jQuery in Action: Build 8 jQuery Projects                       1
# ...

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.histplot(data['subject'])
plt.xlabel('Subjects')
plt.ylabel('No of courses per subject',fontsize=13)
plt.xticks(rotation=60)
plt.show()
# Out:
# C:\Users\Bhavya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
### For which level udemy courses providing courses
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
data['level'].value_counts()
# Out:
# level
# All Levels            1928
# Beginner Level        1269
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.histplot(data['level'])
plt.xlabel('Levels')
plt.ylabel('No of levels ',fontsize=13)
plt.xticks(rotation=60)
plt.show()
# Out:
# C:\Users\Bhavya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
####display the count of paid and free courses
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3366
# False     310
# Name: count, dtype: int64

# %%
sns.countplot (data['is_paid'])
plt.xlabel('No of free and paid courses')
plt.ylabel('No of courses ',fontsize=13)
plt.xticks(rotation=65)
plt.show()

# %%
#### Which course has more lectures (free or paid)?
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
data.groupby(['is_paid']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...

# %%
##courses with higher no of subscribers

data.head()

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=data)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
sns.barplot(x='level',y='num_subscribers',data=data)
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %%
###Most popular course title
data.columns

# %%
data['course_title'].value_counts()
# Out:
# course_title
# Creating an animated greeting card via Google Slides      3
# Acoustic Blues Guitar Lessons                             3
# Drum Lessons For Beginners                                2
# Aprende a tocar el acordeón de botones                    2
# Introduction to Web Development                           2
#                                                          ..
# Financial Analysis:  A Recipe for Success                 1
# Financial analysis: Compare performance of companies      1
# Financial and Business Simulation with Microsoft Excel    1
# Financial Management - A Complete Study                   1
# Zombie Apocalypse Photoshop Actions                       1
# Name: count, Length: 3667, dtype: int64

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]['course_title']
# Out:
# 2230    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
####10 most popular courses as per course title
data.columns

# %%
top_10=data.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
sns.barplot(y='course_title',x='num_subscribers',data=top_10)

plt.show()

# %%
####course with highest no of reviews

data.columns

# %%
data1=data.sort_values(by='num_reviews',ascending=False)['subject']
data1
# Out:
# 3385     Web Development
# 3316     Web Development
# 285      Web Development
# 2034     Web Development
# 2610     Web Development
#               ...
# 1382      Graphic Design
# 1379    Business Finance
# 3427    Business Finance
# 1351    Business Finance
# 2418    Business Finance
# Name: subject, Length: 3676, dtype: object

# %%
plt.figure(figsize=(10,4))
sns.barplot(y='num_reviews',x='subject',data=data)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %%
####does price affect no of reviews

plt.figure(figsize=(15,6))
sns.scatterplot(x='price',y='num_reviews',data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
####courses related to python
data.head()

# %%
data['subject'].value_counts()

# %%
len(data[data['course_title'].str.contains('Python')])
# Out:
# 29

# %%
#### 10 most popular python courses as per no of subscribers
top=data[data['course_title'].str.contains('Python')].sort_values('num_subscribers',ascending=False).head(10)

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='course_title',x='num_subscribers',data=top)
plt.xticks(rotation=60)
plt.show()

# %%
#### in which year highest no of courses were posted
data.head()

# %%
data['Year']=data['published_timestamp'].dt.year

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration       published_timestamp              subject
# ...

# %%
sns.counttplot('Year',data=data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sns.counttplot('Year',data=data)
#
# AttributeError: module 'seaborn' has no attribute 'counttplot'

# %%
#####display category wise count of posted subjects (year wise)
data1=data.groupby('Year')['subject'].value_counts()

# %%
data1
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       227
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
