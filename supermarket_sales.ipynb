# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\Bhavya\Downloads\supermarket_sales - Sheet1.csv',  parse_dates=['Date'])

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
sns.countplot(data.isnull())
plt.figure(figsize=(10,8))

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
###aggregate sales among branches

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.groupby('Branch')['Total'].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
data['Branch'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Branch'].hist()
# Out:
# <Axes: >

# %%
###most popular sales method by customers

# %%
data['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
data['Payment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment'>

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique()>10:
       num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
#####Distribution of Ratings

# %%
sns.distplot(data['Rating'])
# Out:
# C:\Users\Bhavya\AppData\Local\Temp\ipykernel_12636\3093624430.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Rating'])
# C:\Users\Bhavya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
data['cogs'].hist()
# Out:
# <Axes: >

# %%
sns.distplot(data['cogs'])
# Out:
# C:\Users\Bhavya\AppData\Local\Temp\ipykernel_12636\4282832329.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['cogs'])
# C:\Users\Bhavya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
if value id positive data is right skewed
if value is negative data is left skewed

# %%
sns.boxplot(data['cogs'])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=data['cogs'],y=data['Rating'])
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
sns.scatterplot(x=data['gross income'],y=data['Rating'])
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
####most profitable branch as per gross income




data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.sort_values(by=('gross income'),ascending=False)['Branch'].head()
# Out:
# 350    C
# 167    A
# 557    C
# 699    C
# 996    B
# Name: Branch, dtype: object

# %%
sns.barplot(x=data['Branch'],y=data['gross income'],hue=data['City'])
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x=data['Gender'],y=data['gross income'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x=data['Gender'],y=data['gross income'],hue=data['Customer type'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.sort_values(by=('gross income'),ascending=False)['Product line']
# Out:
# 350    Fashion accessories
# 167    Fashion accessories
# 557     Food and beverages
# 699     Home and lifestyle
# 996     Home and lifestyle
#               ...
# 402     Home and lifestyle
# 443    Fashion accessories
# 223    Fashion accessories
# 629    Fashion accessories
# 822      Sports and travel
# Name: Product line, Length: 1000, dtype: object

# %%
data1=data.groupby('Product line')

# %%
sns.barplot(x=data['Product line'],y=data['gross income'])

plt.xticks(rotation=80)
plt.show()

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(x=data['Product line'],y=data['Unit price'])
plt.xticks(rotation=80)
plt.show()

# %%
data.sort_values(by='Unit price',ascending=False)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 983  148-41-7930      C  Naypyitaw        Normal    Male    Health and beauty
# 122  219-22-9386      B   Mandalay        Member    Male    Sports and travel
# 930  641-62-7288      B   Mandalay        Normal    Male   Home and lifestyle
# 494  437-53-3084      B   Mandalay        Normal    Male  Fashion accessories
# 283  667-92-0055      A     Yangon        Member    Male    Health and beauty
# ..           ...    ...        ...           ...     ...                  ...
# 881  115-38-7388      C  Naypyitaw        Member  Female  Fashion accessories
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 784  516-77-6464      C  Naypyitaw        Member  Female    Health and beauty
# 572  239-48-4278      A     Yangon        Member    Male   Food and beverages
# 944  333-23-2632      A     Yangon        Member    Male    Health and beauty
#
# ...

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.groupby('Product line')['Quantity'].sum()
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Name: Quantity, dtype: int64

# %%
sns.barplot(x=data['Product line'],y=data['Quantity'])
plt.xticks(rotation=80)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Health and beauty'),
#   Text(1, 0, 'Electronic accessories'),
#   Text(2, 0, 'Home and lifestyle'),
#   Text(3, 0, 'Sports and travel'),
#   Text(4, 0, 'Food and beverages'),
#   Text(5, 0, 'Fashion accessories')])

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
data['Date'].dt.dayofweek.map({1:'monday',2:'tuesday',3:'wednesday',4:'thursday',5:'friday',6:'saturday',7:'sunday'}).value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
##highest month for sales
data['Date'].dt.month.map({1:'january',2:'february',3:'march',4:'april',5:'may',6:'june',7:'july',8:'august',9:'september'
                           ,10:'october',11:'november',12:'december'}).value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>
